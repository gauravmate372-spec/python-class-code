# %%
#logical and operator

# %%
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True - False
# Out:
# 1

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
5 > 1
# Out:
# True

# %%
5 > 5
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
5 >= 5
# Out:
# True

# %%
5 >= 10
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 > 1 & 10 < 20 #True & True
# Out:
# True

# %%
'hello' == 'hello'
# Out:
# True

# %%
'Hello' == 'hello'
# Out:
# False

# %%
a = 5

# %%
5 == 5
# Out:
# True

# %%
a == 5
# Out:
# True

# %%
'exit' == 'exit'
# Out:
# True

# %%
'Hi' != 'By'
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
'Hello' != 'hello'
# Out:
# True

# %%
'exit' != 'exit'
# Out:
# False

# %%
'hi'
# Out:
# 'hi'

# %%
age = 50

# %%
print('my age is' , age)
# Out:
# my age is 50

# %%
print(f'my age is {age} and i am very good person ')
# Out:
# my age is 50 and i am very good person

# %%
name = 'xyz'

# %%
print(f'my name is {name} and my age is {age}')
# Out:
# my name is xyz and my age is 50

# %%
name = input(' write your good name')
print (f'my name is {name}')
# Out:
#  write your good name Gaurav
# my name is Gaurav

# %%
type(name)
# Out:
# str

# %%
age = input('Enter your age' )
print(f' your age is {age}')
# Out:
# Enter your age 19
#  your age is 19

# %%
type(age)
# Out:
# str

# %%
age = int(input('Enter your age'))
print(f'your age is {age}')
# Out:
# Enter your age 19
# your age is 19

# %%
type(age)
# Out:
# int

# %%
#input ---> str

# %%
student_name = input(Enter student name')
marks = float(input('Enter your marks'))
print(f'student name is {student_name}and marks are {marks}')
# Out:
#   Cell In[45], line 1
#     student_name = input(Enter student name')
#                                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Data structures

# %%
#list

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
mix = [1,15.2,10+5j,True, 'hello']

# %%
mix
# Out:
# [1, 15.2, (10+5j), True, 'hello']

# %%
type(mix)
# Out:
# list

# %%
names = ['om','sham','Gaurac','ramesh']

# %%
names
# Out:
# ['om', 'sham', 'Gaurac', 'ramesh']
