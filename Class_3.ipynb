# %%
f=open("class.txt","a")
f.write("Arjun")
f.close()

# %%
f=open("class.txt","r+")
print(f.read())
f.seek(0)
f.write("Amit")
f.close()
# Out:
# AmititAmitArjunArjun

# %%
f=open("classes.txt","a")
f.write("Arjun")
f.close()

# %%
f=open("classes.txt","r+")
f.read()
f.seek(0)
f.write("Aman")
f.close()

# %%
f1=open("classes.txt","a+")
f1.write("\n abc")
f1.write("\n pqr")
f1.seek(0)
f1.read()
f1.close()

# %%
file = open("attendence.txt","w+")
students = ['rahul','om','shyam']
for name in students:
    file.write(name + "\n")
file.seek(0)
print("Today's Attendence")
print(file.read())
file.close()
# Out:
# Today's Attendence
# rahul
# om
# shyam

# %%
file=open("Visitor.txt","a+")
name=input("Enter visitor name")
file.write(name+"\n")
file.seek(0)
print("\n visitor register")
print(file.read())
file.close()
# Out:
# Enter visitor name Gaurav
#  visitor register
# Gaurav

# %%
file=open("Employee.txt","a+")
emp_id=input("enter Employee id")
emp_name=i
