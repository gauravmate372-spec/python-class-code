# %%
f = open('genai.txt', mode='r+')

# %%
f.readlines()
# Out:
# ['Generative artificial intelligence (GenAI) is a subfield of artificial intelligence intelligence (AI)\n',
#  'that uses generative models to generate text, images, videos,audio,software code or other forms of data.[1]\n',
#  'these models learn the underlying patterns and structures of their training data , and use them to generate new data [2]\n',
#  'in response to input, which often takes the form of natural language prompts.']

# %%
f.seek(0)
# Out:
# 0

# %%
for sentence in f.readlines():
    print(sentence.split(' '))
# Out:
# ['Generative', 'artificial', 'intelligence', '(GenAI)', 'is', 'a', 'subfield', 'of', 'artificial', 'intelligence', 'intelligence', '(AI)\n']
# ['that', 'uses', 'generative', 'models', 'to', 'generate', 'text,', 'images,', 'videos,audio,software', 'code', 'or', 'other', 'forms', 'of', 'data.[1]\n']
# ['these', 'models', 'learn', 'the', 'underlying', 'patterns', 'and', 'structures', 'of', 'their', 'training', 'data', ',', 'and', 'use', 'them', 'to', 'generate', 'new', 'data', '[2]\n']
# ['in', 'response', 'to', 'input,', 'which', 'often', 'takes', 'the', 'form', 'of', 'natural', 'language', 'prompts.']

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Generative artificial intelligence (GenAI) is a subfield of artificial intelligence intelligence (AI)\nthat uses generative models to generate text, images, videos,audio,software code or other forms of data.[1]\nthese models learn the underlying patterns and structures of their training data , and use them to generate new data [2]\nin response to input, which often takes the form of natural language prompts.'

# %%
f.seek(0)
# Out:
# 0

# %%
words = f.read().split(' ' )

# %%
words
# Out:
# ['Generative',
#  'artificial',
#  'intelligence',
#  '(GenAI)',
#  'is',
#  'a',
#  'subfield',
#  'of',
#  'artificial',
#  'intelligence',
#  'intelligence',
#  '(AI)\nthat',
#  'uses',
#  'generative',
#  'models',
#  'to',
#  'generate',
#  'text,',
#  'images,',
#  'videos,audio,software',
#  'code',
#  'or',
#  'other',
#  'forms',
#  'of',
#  'data.[1]\nthese',
#  'models',
#  'learn',
#  'the',
#  'underlying',
#  'patterns',
#  'and',
#  'structures',
#  'of',
#  'their',
#  'training',
#  'data',
#  ',',
#  'and',
#  'use',
#  'them',
#  'to',
#  'generate',
#  'new',
#  'data',
#  '[2]\nin',
#  'response',
#  'to',
#  'input,',
#  'which',
#  'often',
#  'takes',
#  'the',
#  'form',
#  'of',
#  'natural',
#  'language',
#  'prompts.']

# %%
wcount =[]
for word in words:
    print(word,words.count(word))
# Out:
# Generative 1
# artificial 2
# intelligence 3
# (GenAI) 1
# is 1
# a 1
# subfield 1
# of 4
# artificial 2
# intelligence 3
# intelligence 3
# (AI)
# that 1
# uses 1
# generative 1
# models 2
# to 3
# generate 2
# text, 1
# images, 1
# videos,audio,software 1
# code 1
# or 1
# other 1
# forms 1
# of 4
# data.[1]
# these 1
# models 2
# learn 1
# the 2
# underlying 1
# patterns 1
# and 2
# structures 1
# of 4
# their 1
# training 1
# data 2
# , 1
# and 2
# use 1
# them 1
# to 3
# generate 2
# new 1
# data 2
# [2]
# in 1
# response 1
# to 3
# input, 1
# which 1
# often 1
# takes 1
# the 2
# form 1
# of 4
# natural 1
# language 1
# prompts. 1

# %%
[1,1,1,1,1,2,2].count(1)
# Out:
# 5

# %%
'data.[1]'.replace('.[1]','')
# Out:
# 'data'

# %%
'hello'.replace('l','i')
# Out:
# 'heiio'

# %%
'hello'.replace('&','@')
# Out:
# 'hello'

# %%
wcount = []
for word in words:
    wcount.append(words.count(word))

# %%
wcount
# Out:
# [1,
#  2,
#  3,
#  1,
#  1,
#  1,
#  1,
#  4,
#  2,
#  3,
#  3,
#  1,
#  1,
#  1,
#  2,
#  3,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  4,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  4,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  3,
#  2,
#  1,
#  2,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  2,
#  1,
#  4,
#  1,
#  1,
#  1]

# %%
wcount_word = []
for word in words:
    wcount_word.append(word)

# %%
wcount_word
# Out:
# ['Generative',
#  'artificial',
#  'intelligence',
#  '(GenAI)',
#  'is',
#  'a',
#  'subfield',
#  'of',
#  'artificial',
#  'intelligence',
#  'intelligence',
#  '(AI)\nthat',
#  'uses',
#  'generative',
#  'models',
#  'to',
#  'generate',
#  'text,',
#  'images,',
#  'videos,audio,software',
#  'code',
#  'or',
#  'other',
#  'forms',
#  'of',
#  'data.[1]\nthese',
#  'models',
#  'learn',
#  'the',
#  'underlying',
#  'patterns',
#  'and',
#  'structures',
#  'of',
#  'their',
#  'training',
#  'data',
#  ',',
#  'and',
#  'use',
#  'them',
#  'to',
#  'generate',
#  'new',
#  'data',
#  '[2]\nin',
#  'response',
#  'to',
#  'input,',
#  'which',
#  'often',
#  'takes',
#  'the',
#  'form',
#  'of',
#  'natural',
#  'language',
#  'prompts.']

# %%
f.close()

# %%
#python

# %%
a = 5

# %%
a + 5
# Out:
# 10

# %%
a * 2
# Out:
# 10

# %%
f = open('myfile.py', mode='w')

# %%
f.write("""# This is myfile created by file handling
def square(n):
    return n*n
def even_odd(n):
    if n%2 == 0:
        return 'even num',n
    else:
        return 'odd num', n
""")
# Out:
# 172

# %%
f.close()

# %% [markdown]
# Exception handling

# %%
a = 5
print(a+5)
print(a-1)
print(a + 'hello')
print(a*2)
# Out:
# 10
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2 print(a+5)
#       3 print(a-1)
# ----> 4 print(a + 'hello')
#       5 print(a*2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %%
try:
    a = 5
    print(a)
except Exception as e:
    print(e)
# Out:
# 5

# %%
a + 'Hello'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 a + 'Hello'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    a = 5
    print(a)
except Exception as e:
    print(e)
# Out:
# 5

# %%
try:
    a = 10
    print(a/0)
except Exception as e:
    print('Error in division by zero at line no 3')
# Out:
# Error in division by zero at line no 3

# %%
try:
    a = 10
except:
    print('Error in line no 2 while assigning a variable')
try:
    print(a/0)
except:
    print('Error in divison by zero at line no 3')
try:
            print(a+5)
except:
    print('Error in line no 7 while doing conc op b/w a+5')
# Out:
# Error in divison by zero at line no 3
# 15
