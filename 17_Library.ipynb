# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
np.random.randint(100,150,3)
# Out:
# array([123, 145, 145], dtype=int32)

# %%
np.random.randint(1,15,1)
# Out:
# array([8], dtype=int32)
