# %%
def square(n):
    return n*n
    def even_odd(n):
        if n % 2 == 0:
            return('even',n)
        else:
            return('odd',n)

# %%
import func1
print(func1.square(7))
print(even_odd(7))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import func1
#       2 print(func1.square(7))
#       3 print(even_odd(7))
#
# ModuleNotFoundError: No module named 'func1'
