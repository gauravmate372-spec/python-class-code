# %%
if 1 > 5:
    print(True)
else: 
    print(False)
# Out:
# False

# %%
1 > 5
# Out:
# False

# %%
if 10 > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Fail

# %%
marks = float(input('input your marks'))
if marks > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# input your marks 95
# Pass

# %%
marks = float(input('Enter your marks'))
if marks >= 90:
    print('A')
elif marks >= 70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 92
# A

# %%
#course info

# %%
course = input('Enter your course name')
if course == 'python':
    print('yes we have python course')
elif couse == 'java':
    print('we have java course')
else:
    print('fwe dont have{course} course.')
# Out:
# Enter your course name python
# yes we have python course

# %%
'java' == 'python'
# Out:
# False

# %%
'java' == 'java'
# Out:
# True

# %%
'JAVA'. lower()
# Out:
# 'java'

# %%
coupan = input('Enter your coupan code')
total = float(input('Enter your totall bill'))
if coupan == 'DATA50':
    discount = total * 0.5
    print('you will get discount of{discount}')
    final_price = print('your final total bill is {total - discount}')
# Out:
# Enter your coupan code 600
# Enter your totall bill 1000

# %%
100 * 0.7
# Out:
# 70.0

# %%
100 * 0.5
# Out:
# 50.0

# %%
#similar code for course, discount

# %%
marks = float(input('Enter your marks'))
if marks >= 90:
    print('A')
elif marks >= 70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35:
    print('Pass')
else: 
    print('Fail')
# Out:
# Enter your marks 94
# A

# %%
marks = float(input('Enter your marks'))
if marks >= 90 and marks <= 100: #True and False --->f
    print('A')
elif marks >= 70 and marks < 90: #True and False
    print('B')
elif marks >= 50 and marks < 70: #True and False
    print('C')
elif marks >= 35 and marks < 50: #True and False
    print('Pass')
elif marks >= 0 and marks < 35: #True and False
    print('Fail')
else:
    print('Please write marks between 0-100 range')
# Out:
# Enter your marks 95
# A

# %%
120 > 90
# Out:
# True

# %%
120 >= 90
# Out:
# True

# %%
120 <= 100
# Out:
# False

# %%
#even odd

# %%
10 % 2 #--->Even
# Out:
# 0

# %%
9 % 2 #--->Odd
# Out:
# 1

# %%
num = int(input('Enter your num'))
if num % 2 == 0:
    print('Even num' , num)
elif num % 2 != 0:
    print('even num', num)
else:
    print('please rewrite num')
# Out:
# Enter your num 3
# even num 3
