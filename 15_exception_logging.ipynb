# %%
def even_odd(n):
    try:
        if n % 2 == 0:
            return 'Even no', n
        else:
            return 'Odd', n
    except Exception as e:
        print('Error in even_odd func')
        print(e)

# %%
even_odd('h')
# Out:
# Error in even_odd func
# not all arguments converted during string formatting

# %% [markdown]
# Logging

# %%
import logging

# %%
logging.info('This is my info log')
logging.error('This is my error log')
logging.debug('This is my debug log')

# %%
import logging

# %%
logging.basicConfig(filename='new.log' ,level = logging.INFO,
                    format= "%(asctime)s - %(levelname)s - %(message)s")

# %%
# time - level - message

# %%
a = int(input('Enter num a'))
b = int(input('Enter num b'))
result = a*b
# Out:
# Enter num a 3
# Enter num b 2

# %%
logging.info("project1 started")
try:
    a = int(input('Enter num a'))
    b = int(input('Enter num b'))
    logging.info(f'we have received value for a {a} and b {b}')
    result = a*b
    logging.info(f'result for {a} and {b} is {result}')
    print(reslut)
except exception as e:
    logging.error('Error in try blog taking input or multiplication')
    logging.error(e)
# Out:
# Enter num a 3
# Enter num b 6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       7     logging.info(f'result for {a} and {b} is {result}')
# ----> 8     print(reslut)
#       9 except exception as e:
#
# NameError: name 'reslut' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       7     logging.info(f'result for {a} and {b} is {result}')
#       8     print(reslut)
# ----> 9 except exception as e:
#      10     logging.error('Error in try blog taking input or multiplication')
#      11     logging.error(e)
#
# NameError: name 'exception' is not defined

# %%
logging.shutdown()

# %%
import logging
logging.basicConfig(filename='project1.log', level = logging.INFO,
                    format= "%(asctime)s - %(levelname)s - %message)s")

# %%
def div(a,b):
    logging.info(f'value for a {a} and b{b}')
    try:
        result = a / b
        logging.info('result for {a} and {b} is {result}')
        logging.info('project completed')
        return result
# Out:
#   Cell In[20], line 7
#     return result
#                  ^
# _IncompleteInputError: incomplete input

# %%
def div(a,b):
    logging.info(f'value for a {a} and b{b}')
    try:
        result = a / b
        logging.info(f'result for {a} and {b} is {result}')
        logging.info(f'project completed')
        return result
    except exception as e:
        logging.error('Error in div function')
        logging.error(e)

# %%
div(10,20
# Out:
#   Cell In[22], line 1
#     div(10,20
#              ^
# _IncompleteInputError: incomplete input
